# %% [markdown]
# # Respostas · Aula 02A · Diferenças finitas
#
# As soluções dos 🎯 do caderno `aula02a-diferencas-finitas.ipynb`. Tente antes de abrir: é a tentativa, inclusive a errada, que fixa.
#
# Há sempre mais de uma solução certa — esta é uma delas.

# %% [markdown]
# ## 🎯 A função central

# %%
def central(f, x, h):
    return (f(x + h) - f(x - h)) / (2 * h)

# %% [markdown]
# ## 🎯 Acelerando ou freando?

# %%
def fase(t):
    h = 0.01
    d2 = (P(t + h) - 2 * P(t) + P(t - h)) / h**2
    if d2 > 0:
        return "acelerando"
    return "freando"
